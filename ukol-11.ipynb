# %%
import pandas as pd
import matplotlib.pyplot as plt
platy_2021_02 = pd.read_csv("platy_2021_02.csv")
platy_2021_02["plat"].plot(kind="hist", bins=10, edgecolor="black", color="pink")
plt.xlabel("Plat")
plt.ylabel("Počet")
plt.title("Platy")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
